# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Aryan Sharma**
# Astrophysicist

# %% [markdown]
# *I am interested in data science because it's a key/necessary skill for most career paths. Being able to understand data, and make changes based on that understanding is and will continue to be instrumental in the growth of technology and the human race.*

# %% [markdown]
# ### In the following line, my code is supposed to perform and output the answer of a simple subtraction equation.

# %%
15-14

# %% [markdown]
# ~~easy~~
# [(https://www.si.com/nfl/49ers/news/why-the-san-francisco-49ers-have-their-best-chance-at-winning-the-super-bowl)]
# * basketball
# * football
# * baseball
# ![cmc.jpeg](attachment:cmc.jpeg)

# %%
1
